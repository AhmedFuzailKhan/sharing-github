# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\eahkhan\\Desktop\\jupyter notebook'

# %%
df = pd.read_csv('titanic.csv',delimiter=",") #To Read File
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(pd.read_excel('test.xls')) #to read Excel file

# %%
type(pd.read_csv('titanic.csv',delimiter="\t"))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('test.xls')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(-5) #Excluding bottom 5 rows
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
z=np.where(df.Age.isna())  #find indexes of nan in Age series Output is tupple
list(z[0]) #convert output tupple to list
# Out:
# [5,
#  17,
#  19,
#  26,
#  28,
#  29,
#  31,
#  32,
#  36,
#  42,
#  45,
#  46,
#  47,
#  48,
#  55,
#  64,
#  65,
#  76,
#  77,
#  82,
#  87,
#  95,
#  101,
#  107,
#  109,
#  121,
#  126,
#  128,
#  140,
#  154,
#  158,
#  159,
#  166,
#  168,
#  176,
#  180,
#  181,
#  185,
#  186,
#  196,
#  198,
#  201,
#  214,
#  223,
#  229,
#  235,
#  240,
#  241,
#  250,
#  256,
#  260,
#  264,
#  270,
#  274,
#  277,
#  284,
#  295,
#  298,
#  300,
#  301,
#  303,
#  304,
#  306,
#  324,
#  330,
#  334,
#  335,
#  347,
#  351,
#  354,
#  358,
#  359,
#  364,
#  367,
#  368,
#  375,
#  384,
#  388,
#  409,
#  410,
#  411,
#  413,
#  415,
#  420,
#  425,
#  428,
#  431,
#  444,
#  451,
#  454,
#  457,
#  459,
#  464,
#  466,
#  468,
#  470,
#  475,
#  481,
#  485,
#  490,
#  495,
#  497,
#  502,
#  507,
#  511,
#  517,
#  522,
#  524,
#  527,
#  531,
#  533,
#  538,
#  547,
#  552,
#  557,
#  560,
#  563,
#  564,
#  568,
#  573,
#  578,
#  584,
#  589,
#  593,
#  596,
#  598,
#  601,
# ...

# %%
df.drop(list(np.where(df.Age.isna())[0]), axis=0) # drop rows where 'Age' Series is "Missing Value" NaN
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.tail(-5) #excluding Top 5 rows
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head() #Top 5 Rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info() # get count and type information for rach column ans missing values (nan)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          156 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     156 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
df.isna().sum() # get sum of missing values in each series
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].dropna().mean() #average of series after droping "missing values" nan
# Out:
# 28.141507936507935

# %%
df['Age'].mean() #average of series
# Out:
# 29.69911764705882

# %%
df.mean()  # mean of each int,float series
# Out:
# C:\Users\eahkhan\AppData\Local\Temp/ipykernel_444/2678247265.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()  # mean of each int,float series
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.Age.fillna(df['Age'].mean(), inplace=True) # to fill "Missing values" in series Age with average value of age and inplace

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age']=df.Age.fillna(df['Age'].mean()) # to fill "Missing values" in series Age with average value of age and asign result to 'Age' series

# %%
df.Embarked.fillna(df.Embarked.mode()[0], inplace=True) # to fill "missing values" with most occuring value usinf mode() function

# %%
df.Embarked.isna().sum() #checking any missing value in embarked by sum of "missing values" nan
# Out:
# 2

# %%
df['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isna().sum() # get sum of missing values in each series
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop([151,152], axis=0)     #drop row number 155, (axis=0) means row
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 149          150         0       2
# 150          151         0       2
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Cabin',axis=1, inplace = True) #drop series 'Cabin', (axis=1) means column. inplace means to over write active dataframe

# %%
df['Embarked'].fillna(df.Embarked.mode()[0] , inplace=True) # to fill "missing values" with most occuring value usinf mode() function
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 151    S
# 152    S
# 153    S
# 154    S
# 155    C
# Name: Embarked, Length: 156, dtype: object

# %%
df['Embarked'].isna().sum()
# Out:
# 0

# %%
z[61] is np.nan
# Out:
# True

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.index #index range attribute, can be used to itterate over the series/data frame
#for x in df.index:
#    print(x)
# Out:
# RangeIndex(start=0, stop=156, step=1)

# %%
df.drop(['Embarked','Name','Ticket'] , axis=1)        #Drop series
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 151          152         1       1  female  22.000000      1      0  66.6000
# 152          153         0       3    male  55.500000      0      0   8.0500
# 153          154         0       3    male  40.500000      0      2  14.5000
# 154          155         0       3    male  28.141508      0      0   7.3125
# 155          156         0       1    male  51.000000      0      1  61.3792
#
# [156 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.groupby('Sex')['Age'].mean()     #group by different instances of series in () and funtion on series in []
# Out:
# Sex
# female    28.216730
# male      30.505824
# Name: Age, dtype: float64

# %%
df.groupby(['Survived','Sex'])[['Age','Pclass']].mean()    #Multiple group by different instances of series in () and funtion on series in []
# Out:
#                        Age    Pclass
# Survived Sex
# 0        female  26.023272  2.851852
#          male    31.175224  2.476496
# 1        female  28.979263  1.918455
#          male    27.631705  2.018349

# %%
df['Embarked']=pd.get_dummies(df.Embarked, drop_first=True) # get dummy values for each unique instance in a series. drop_first will reduce the model to n-1

# %%
df['coded'] = df.Sex.apply(lambda x: 1 if x=='female' else 0) # add series and apply function on series

# %%
q1= pd.get_dummies(df.Sex,drop_first=True)
q1.head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
pd.get_dummies(df.Sex).head(5)
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
pd.concat([df,q1,],axis=1).head(2).drop('Name', axis=1)      #concatinate dataframes
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Ticket  \
# 0            1         0       3    male  22.0      1      0  A/5 21171
# 1            2         1       1  female  38.0      1      0   PC 17599
#
#       Fare Cabin  Embarked  coded  male
# 0   7.2500   NaN         0      0     1
# 1  71.2833   C85         0      1     0

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked  coded
# 0      0         A/5 21171   7.2500   NaN         0      0
# 1      0          PC 17599  71.2833   C85         0      1
# 2      0  STON/O2. 3101282   7.9250   NaN         0      1
# 3      0            113803  53.1000  C123         0      1
# ...

# %%
pd.get_dummies(df.Sex, drop_first=True).head(5)
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
df.Sex.apply(lambda x : 1 if x == 'female' else 0)   #apply lambda function
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 151    1
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Sex, Length: 156, dtype: int64

# %%
z = np.array([df.Sex.apply(lambda x : 1 if x == 'female' else 0)])
d1 = pd.DataFrame(data=z[0],columns=['Sex2'])       #Convert dictonary into dataframe 
d1.head(5)
# Out:
#    Sex2
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0

# %%
pd.concat([df,d1],axis=1)        # concatination of two data frames axis=1 defined the column operation
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.where(df.Sex =='female').sort_values(by=['Sex','Age'])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 119        120.0       0.0     3.0         Andersson, Miss. Ellis Anna Maria
# 43          44.0       1.0     2.0  Laroche, Miss. Simonne Marie Anne Andree
# 10          11.0       1.0     3.0           Sandstrom, Miss. Marguerite Rut
# 58          59.0       1.0     2.0              West, Miss. Constance Mirium
# 24          25.0       0.0     3.0             Palsson, Miss. Torborg Danira
# ..           ...       ...     ...                                       ...
# 150          NaN       NaN     NaN                                       NaN
# 152          NaN       NaN     NaN                                       NaN
# 153          NaN       NaN     NaN                                       NaN
# 154          NaN       NaN     NaN                                       NaN
# 155          NaN       NaN     NaN                                       NaN
#
# ...

# %%
df.iloc[np.where(df.Sex=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
np.where(df.Sex=='female')
# Out:
# (array([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,  19,  22,  24,
#          25,  28,  31,  32,  38,  39,  40,  41,  43,  44,  47,  49,  52,
#          53,  56,  58,  61,  66,  68,  71,  79,  82,  84,  85,  88,  98,
#         100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140,
#         141, 142, 147, 151], dtype=int64),)

# %%
df.Sex=='female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 151     True
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Sex, Length: 156, dtype: bool

# %%
df.iloc[np.where(df.Sex=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
df.iloc[np.where(df.Sex =='female')].sort_values(by=['Pclass','Age'])
# Out:
#      PassengerId  Survived  Pclass  \
# 136          137         1       1
# 151          152         1       1
# 88            89         1       1
# 31            32         1       1
# 3              4         1       1
# 1              2         1       1
# 61            62         1       1
# 52            53         1       1
# 11            12         1       1
# 43            44         1       2
# 58            59         1       2
# 9             10         1       2
# 84            85         1       2
# 56            57         1       2
# 41            42         0       2
# 53            54         1       2
# 66            67         1       2
# 133          134         1       2
# 123          124         1       2
# 98            99         1       2
# 15            16         1       2
# 119          120         0       3
# 10            11         1       3
# 24            25         0       3
# 147          148         0       3
# ...

# %%
pd.get_dummies(df, columns=['Sex','Embarked'],drop_first=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      1
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      1
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %%
# Out:
#                                    Name   Sex  Ticket Cabin
# count                               156   156     156    31
# unique                              156     2     145    28
# top     Greenfield, Mr. William Bertram  male  349909  C123
# freq                                  1   100       2     2

# %%
df.describe()      #summary of numaric data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare    Embarked       coded
# count  156.000000  156.000000  156.000000  156.000000
# mean     0.397436   28.109587    0.083333    0.358974
# std      0.870146   39.401047    0.277276    0.481245
# min      0.000000    6.750000    0.000000    0.000000
# 25%      0.000000    8.003150    0.000000    0.000000
# ...

# %%
df.describe(include=['object'])     #summary of object data
# Out:
#                                    Name   Sex  Ticket Cabin
# count                               156   156     156    31
# unique                              156     2     145    28
# top     Greenfield, Mr. William Bertram  male  349909  C123
# freq                                  1   100       2     2

# %%
df.describe(include=['object'])['Cabin']['freq']    # access items from data frame
# Out:
# 2

# %%
df.describe()[['Age','Fare']]                  #access summary of multiple series from dataframe
# Out:
#               Age        Fare
# count  126.000000  156.000000
# mean    28.141508   28.109587
# std     14.613880   39.401047
# min      0.830000    6.750000
# 25%     19.000000    8.003150
# 50%     26.000000   14.454200
# 75%     35.000000   30.371850
# max     71.000000  263.000000

# %%
df.describe()[['Age','Fare']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.describe()[['Age','Fare']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df.describe()[['Age','Fare']].plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.describe()[['Age','Fare']].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.describe()['Fare'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Survived.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df.describe(include='O')
# Out:
#                                    Name   Sex  Ticket Cabin
# count                               156   156     156    31
# unique                              156     2     145    28
# top     Greenfield, Mr. William Bertram  male  349909  C123
# freq                                  1   100       2     2

# %%
display(df.Survived.value_counts(),df.Survived.value_counts(normalize=True))
# Out:
# 0    102
# 1     54
# Name: Survived, dtype: int64
# 0    0.653846
# 1    0.346154
# Name: Survived, dtype: float64

# %%
df.groupby('Survived')['Sex'].value_counts()
# Out:
# Survived  Sex
# 0         male      86
#           female    16
# 1         female    40
#           male      14
# Name: Sex, dtype: int64
