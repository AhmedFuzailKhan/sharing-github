# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salaries.csv")
# Out:
# C:\Users\eahkhan\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148643                       Human Services Technician       0.00
# ...

# %%
df1_group = df[['Year','TotalPay']].groupby(['Year'])
df1_group

# %%
for each_year in df['Year'].unique():
    display("total payment in the year " + str(each_year) + " is :" + str(df1_group.get_group(each_year)['TotalPay'].sum()))
# Out:
# 'total payment in the year 2011 is :2594113030.72'
# 'total payment in the year 2012 is :2724736317.2299995'
# 'total payment in the year 2013 is :2918655930.8'
# 'total payment in the year 2014 is :2876910951.2599998'

# %%
display("total increase form 2011 to 2014 is : " + str(df1_group.get_group(2014)['TotalPay'].sum() - df1_group.get_group(2011)['TotalPay'].sum()))
# Out:
# 'total increase form 2011 to 2014 is : 282797920.53999996'

# %%
df1_group.get_group(2014)['TotalPay'].sum()

# %%
Df1_filter = df['Year']==2014

# %%
df[Df1_filter]
# Out:
#             Id          EmployeeName                     JobTitle    BasePay  \
# 110529  110532           David Shinn               Deputy Chief 3  129150.01
# 110530  110533            Amy P Hart            Asst Med Examiner  318835.49
# 110531  110534  William J Coaker Jr.     Chief Investment Officer  257340.00
# 110532  110535        Gregory P Suhr              Chief of Police  307450.04
# 110533  110536  Joanne M Hayes-White       Chief, Fire Department  302068.00
# ...        ...                   ...                          ...        ...
# 148643  148646      Carolyn A Wilson    Human Services Technician       0.00
# 148644  148648        Joann Anderson  Communications Dispatcher 2       0.00
# 148645  148649           Leon Walker                    Custodian       0.00
# 148646  148650         Roy I Tillery                    Custodian       0.00
# 148647  148654             Joe Lopez   Counselor, Log Cabin Ranch       0.00
#
# ...

# %%
Df2_filter = df[Df1_filter]['TotalPay']==df[Df1_filter]['TotalPay'].max()

# %%
df[Df1_filter]['TotalPay'].max()
# Out:
# 471952.64

# %%
df[Df1_filter][Df2_filter]
# Out:
#             Id EmployeeName        JobTitle    BasePay  OvertimePay  \
# 110529  110532  David Shinn  Deputy Chief 3  129150.01          0.0
#
#          OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 110529  342802.63  38780.04  471952.64         510732.68  2014    NaN
#
#                Agency Status
# 110529  San Francisco     PT
